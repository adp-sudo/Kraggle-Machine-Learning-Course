# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_36/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape = input_shape),
    layers.Dense(256,activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256,activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1,activation = 'sigmoid')
    
    
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 3s 11ms/step - loss: 0.4839 - binary_accuracy: 0.7705 - val_loss: 0.4516 - val_binary_accuracy: 0.8011
# Epoch 2/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4248 - binary_accuracy: 0.8007 - val_loss: 0.4077 - val_binary_accuracy: 0.8137
# Epoch 3/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4109 - binary_accuracy: 0.8070 - val_loss: 0.3996 - val_binary_accuracy: 0.8146
# Epoch 4/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.4020 - binary_accuracy: 0.8125 - val_loss: 0.3949 - val_binary_accuracy: 0.8179
# Epoch 5/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3987 - binary_accuracy: 0.8146 - val_loss: 0.3887 - val_binary_accuracy: 0.8164
# Epoch 6/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3928 - binary_accuracy: 0.8169 - val_loss: 0.3871 - val_binary_accuracy: 0.8195
# Epoch 7/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3891 - binary_accuracy: 0.8173 - val_loss: 0.3867 - val_binary_accuracy: 0.8237
# Epoch 8/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3863 - binary_accuracy: 0.8213 - val_loss: 0.3808 - val_binary_accuracy: 0.8228
# Epoch 9/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3823 - binary_accuracy: 0.8227 - val_loss: 0.3789 - val_binary_accuracy: 0.8262
# Epoch 10/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3790 - binary_accuracy: 0.8238 - val_loss: 0.3825 - val_binary_accuracy: 0.8250
# Epoch 11/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3772 - binary_accuracy: 0.8249 - val_loss: 0.3757 - val_binary_accuracy: 0.8282
# Epoch 12/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3739 - binary_accuracy: 0.8270 - val_loss: 0.3756 - val_binary_accuracy: 0.8276
# Epoch 13/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3719 - binary_accuracy: 0.8285 - val_loss: 0.3717 - val_binary_accuracy: 0.8311
# Epoch 14/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3697 - binary_accuracy: 0.8291 - val_loss: 0.3681 - val_binary_accuracy: 0.8318
# Epoch 15/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3685 - binary_accuracy: 0.8299 - val_loss: 0.3718 - val_binary_accuracy: 0.8286
# Epoch 16/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3662 - binary_accuracy: 0.8310 - val_loss: 0.3691 - val_binary_accuracy: 0.8323
# Epoch 17/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3655 - binary_accuracy: 0.8306 - val_loss: 0.3740 - val_binary_accuracy: 0.8296
# Epoch 18/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3639 - binary_accuracy: 0.8327 - val_loss: 0.3639 - val_binary_accuracy: 0.8344
# Epoch 19/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3614 - binary_accuracy: 0.8327 - val_loss: 0.3667 - val_binary_accuracy: 0.8323
# Epoch 20/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3596 - binary_accuracy: 0.8340 - val_loss: 0.3639 - val_binary_accuracy: 0.8341
# Epoch 21/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3572 - binary_accuracy: 0.8352 - val_loss: 0.3616 - val_binary_accuracy: 0.8361
# Epoch 22/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3572 - binary_accuracy: 0.8353 - val_loss: 0.3604 - val_binary_accuracy: 0.8349
# Epoch 23/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3559 - binary_accuracy: 0.8355 - val_loss: 0.3605 - val_binary_accuracy: 0.8360
# Epoch 24/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3540 - binary_accuracy: 0.8365 - val_loss: 0.3595 - val_binary_accuracy: 0.8358
# Epoch 25/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3531 - binary_accuracy: 0.8364 - val_loss: 0.3610 - val_binary_accuracy: 0.8357
# Epoch 26/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3520 - binary_accuracy: 0.8373 - val_loss: 0.3579 - val_binary_accuracy: 0.8365
# Epoch 27/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3511 - binary_accuracy: 0.8377 - val_loss: 0.3551 - val_binary_accuracy: 0.8382
# Epoch 28/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3503 - binary_accuracy: 0.8375 - val_loss: 0.3572 - val_binary_accuracy: 0.8367
# Epoch 29/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3495 - binary_accuracy: 0.8382 - val_loss: 0.3565 - val_binary_accuracy: 0.8368
# Epoch 30/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3473 - binary_accuracy: 0.8388 - val_loss: 0.3540 - val_binary_accuracy: 0.8374
# Epoch 31/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3477 - binary_accuracy: 0.8393 - val_loss: 0.3593 - val_binary_accuracy: 0.8339
# Epoch 32/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3443 - binary_accuracy: 0.8410 - val_loss: 0.3550 - val_binary_accuracy: 0.8378
# Epoch 33/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3440 - binary_accuracy: 0.8406 - val_loss: 0.3542 - val_binary_accuracy: 0.8375
# Epoch 34/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3454 - binary_accuracy: 0.8408 - val_loss: 0.3567 - val_binary_accuracy: 0.8374
# Epoch 35/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3421 - binary_accuracy: 0.8415 - val_loss: 0.3530 - val_binary_accuracy: 0.8381
# Epoch 36/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3418 - binary_accuracy: 0.8410 - val_loss: 0.3526 - val_binary_accuracy: 0.8394
# Epoch 37/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3419 - binary_accuracy: 0.8428 - val_loss: 0.3530 - val_binary_accuracy: 0.8383
# Epoch 38/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3401 - binary_accuracy: 0.8434 - val_loss: 0.3519 - val_binary_accuracy: 0.8388
# Epoch 39/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3410 - binary_accuracy: 0.8421 - val_loss: 0.3533 - val_binary_accuracy: 0.8385
# Epoch 40/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3384 - binary_accuracy: 0.8432 - val_loss: 0.3563 - val_binary_accuracy: 0.8374
# Epoch 41/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3386 - binary_accuracy: 0.8429 - val_loss: 0.3534 - val_binary_accuracy: 0.8385
# Epoch 42/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3371 - binary_accuracy: 0.8449 - val_loss: 0.3538 - val_binary_accuracy: 0.8392
# Epoch 43/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3353 - binary_accuracy: 0.8451 - val_loss: 0.3515 - val_binary_accuracy: 0.8398
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
